# %% [markdown]
# ##**DEEP DATASET "MAVEN FUZZY FACTORY"**

# %% [markdown]
# ## #TABLE WEBSITE_SESSIONS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/1xdSUObWQwSIx2EFhmJH2o9Otbu7ei4TghvvVcsmuLl0/edit?gid=125658187#gid=125658187'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_website_sessions = pd.read_csv(potter_csv_export_url)
df_website_sessions
# Out:
#         website_session_id    created_at  user_id  is_repeat_session  \
# 0                        1  3/19/12 8:04        1                  0
# 1                        2  3/19/12 8:16        2                  0
# 2                        3  3/19/12 8:26        3                  0
# 3                        4  3/19/12 8:37        4                  0
# 4                        5  3/19/12 9:00        5                  0
# ...                    ...           ...      ...                ...
# 472866              472867  3/19/15 7:49   394314                  0
# 472867              472868  3/19/15 7:54   394315                  0
# 472868              472869  3/19/15 7:55   394316                  0
# 472869              472870  3/19/15 7:56   394317                  0
# 472870              472871  3/19/15 7:59   394318                  0
#
#        utm_source utm_campaign utm_content device_type  \
# 0         gsearch     nonbrand      g_ad_1      mobile
# ...

# %%
backup1=df_website_sessions.copy()

# %%
df_website_sessions.head()
# Out:
#    website_session_id    created_at  user_id  is_repeat_session utm_source  \
# 0                   1  3/19/12 8:04        1                  0    gsearch
# 1                   2  3/19/12 8:16        2                  0    gsearch
# 2                   3  3/19/12 8:26        3                  0    gsearch
# 3                   4  3/19/12 8:37        4                  0    gsearch
# 4                   5  3/19/12 9:00        5                  0    gsearch
#
#   utm_campaign utm_content device_type             http_referer
# 0     nonbrand      g_ad_1      mobile  https://www.gsearch.com
# 1     nonbrand      g_ad_1     desktop  https://www.gsearch.com
# 2     nonbrand      g_ad_1     desktop  https://www.gsearch.com
# 3     nonbrand      g_ad_1     desktop  https://www.gsearch.com
# 4     nonbrand      g_ad_1      mobile  https://www.gsearch.com

# %%
df_website_sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472871 entries, 0 to 472870
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   website_session_id  472871 non-null  int64
#  1   created_at          472871 non-null  object
#  2   user_id             472871 non-null  int64
#  3   is_repeat_session   472871 non-null  int64
#  4   utm_source          389543 non-null  object
#  5   utm_campaign        389543 non-null  object
#  6   utm_content         389543 non-null  object
#  7   device_type         472871 non-null  object
#  8   http_referer        432954 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 32.5+ MB

# %% [markdown]
# ada data yang bernilai Null dibeberapa column, diantaranya : 1. utm_source (389543 non Null) --> 83328 Null,
# 2. utm_campaign (389543 non Null) --> 83328 Null,
# 3. utm_content (389543 non Null) --> 83328 Null,
# 4. http_referer (432954 non Null) --> 39917 Null

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_website_sessions.dtypes
# Out:
# website_session_id     int64
# created_at            object
# user_id                int64
# is_repeat_session      int64
# utm_source            object
# utm_campaign          object
# utm_content           object
# device_type           object
# http_referer          object
# dtype: object

# %% [markdown]
# tipe data di column created_at perlu diubah dr object ke datetime

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_website_sessions:
    print(df_website_sessions[column].value_counts())
# Out:
# website_session_id
# 472871    1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 12        1
# 11        1
# 10        1
# 9         1
# 8         1
# Name: count, Length: 472871, dtype: int64
# created_at
# 11/28/14 9:39     14
# 11/28/14 12:08    13
# 11/29/13 13:00    13
# 11/29/13 12:45    13
# 11/28/14 15:31    12
#                   ..
# 3/19/15 7:28       1
# 3/19/15 7:29       1
# 3/19/12 8:37       1
# 3/19/12 8:26       1
# 3/19/12 8:16       1
# Name: count, Length: 367237, dtype: int64
# user_id
# 96978     4
# 96977     4
# 322408    4
# 247449    4
# 254911    4
#          ..
# 138157    1
# 138155    1
# 138153    1
# 138152    1
# 138166    1
# Name: count, Length: 394318, dtype: int64
# is_repeat_session
# 0    394318
# 1     78553
# Name: count, dtype: int64
# utm_source
# gsearch       316035
# bsearch        62823
# socialbook     10685
# Name: count, dtype: int64
# utm_campaign
# nonbrand            337615
# brand                41243
# ...

# %%
df_website_sessions['utm_source'].value_counts()
# Out:
# utm_source
# gsearch       316035
# bsearch        62823
# socialbook     10685
# Name: count, dtype: int64

# %%
df_website_sessions['utm_campaign'].value_counts()
# Out:
# utm_campaign
# nonbrand            337615
# brand                41243
# desktop_targeted      5590
# pilot                 5095
# Name: count, dtype: int64

# %%
df_website_sessions['utm_content'].value_counts()
# Out:
# utm_content
# g_ad_1         282706
# b_ad_1          54909
# g_ad_2          33329
# b_ad_2           7914
# social_ad_2      5590
# social_ad_1      5095
# Name: count, dtype: int64

# %%
df_website_sessions['device_type'].value_counts()
# Out:
# device_type
# desktop    327027
# mobile     145844
# Name: count, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table website_sessions

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_website_sessions['website_session_id'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 472866    False
# 472867    False
# 472868    False
# 472869    False
# 472870    False
# Name: website_session_id, Length: 472871, dtype: bool

# %% [markdown]
# setelah pengecekan data duplicate, tdk ditemukan adanya data yg duplicate di column website_session_id, sedangkan untuk column user_id, duplicate data diperbolehkan krn berdasarkan data dictionary, user_id di table website_session bukanlah primery key (PK) yg harus bernilai unik.

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_website_sessions.isnull().sum()
# Out:
# website_session_id        0
# created_at                0
# user_id                   0
# is_repeat_session         0
# utm_source            83328
# utm_campaign          83328
# utm_content           83328
# device_type               0
# http_referer          39917
# dtype: int64

# %% [markdown]
# adanya missing value di column utm_source, utm_campaign, utm_content dan http_referer

# %% [markdown]
# ## DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_website_sessions['created_at'] = pd.to_datetime(df_website_sessions['created_at'], format='%m/%d/%y %H:%M')

# %%
df_website_sessions.dtypes
# Out:
# website_session_id             int64
# created_at            datetime64[ns]
# user_id                        int64
# is_repeat_session              int64
# utm_source                    object
# utm_campaign                  object
# utm_content                   object
# device_type                   object
# http_referer                  object
# dtype: object

# %% [markdown]
# ###melakukan pengisian pada column yg missing value yaitu pada column utm_source, utm_campaign, utm_content dan http_referer

# %%
df_website_sessions['utm_source'].fillna('direct', inplace=True)
df_website_sessions['utm_campaign'].fillna('non_campaign', inplace=True)
df_website_sessions['utm_content'].fillna('generic', inplace=True)
df_website_sessions['http_referer'].fillna('direct', inplace=True)
# Out:
# /tmp/ipython-input-117010731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_website_sessions['utm_source'].fillna('direct', inplace=True)
# /tmp/ipython-input-117010731.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_website_sessions.isnull().sum()
# Out:
# website_session_id    0
# created_at            0
# user_id               0
# is_repeat_session     0
# utm_source            0
# utm_campaign          0
# utm_content           0
# device_type           0
# http_referer          0
# dtype: int64

# %% [markdown]
# ## #TABLE PRODUCTS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/1-M8lhvA0HNPoBJNqL5CuW1TfLkxIKHgXm2EeSN9RFTM/edit?gid=1571018562#gid=1571018562'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_products = pd.read_csv(potter_csv_export_url)
df_products
# Out:
#    product_id     created_at                product_name
# 0           1   3/19/12 8:00      The Original Mr. Fuzzy
# 1           2   1/6/13 13:00       The Forever Love Bear
# 2           3  12/12/13 9:00    The Birthday Sugar Panda
# 3           4   2/5/14 10:00  The Hudson River Mini bear

# %%
backup1=df_products.copy()

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_products.dtypes
# Out:
# product_id       int64
# created_at      object
# product_name    object
# dtype: object

# %% [markdown]
# tipe data di column created_at perlu diubah dr object ke datetime

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    4 non-null      int64
#  1   created_at    4 non-null      object
#  2   product_name  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %% [markdown]
# tidak ditemukan data di column yg bernilai Null

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_products:
    print(df_products[column].value_counts())
# Out:
# product_id
# 1    1
# 2    1
# 3    1
# 4    1
# Name: count, dtype: int64
# created_at
# 3/19/12 8:00     1
# 1/6/13 13:00     1
# 12/12/13 9:00    1
# 2/5/14 10:00     1
# Name: count, dtype: int64
# product_name
# The Original Mr. Fuzzy        1
# The Forever Love Bear         1
# The Birthday Sugar Panda      1
# The Hudson River Mini bear    1
# Name: count, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table products

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_products['product_id'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: product_id, dtype: bool

# %%
df_products['created_at'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: created_at, dtype: bool

# %%
df_products['product_name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: product_name, dtype: bool

# %% [markdown]
# setelah dilakukan pengecekan dengan .duplicated, tdk ditemukan adanya data yg duplicate di semua column pada tabel products

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_products.isnull().sum()
# Out:
# product_id      0
# created_at      0
# product_name    0
# dtype: int64

# %% [markdown]
# setelah dilakukan pengecekan missing value dengan .isnull().sum(), tidak ditemukan adanya data yg missing value di semua column pada tabel products

# %% [markdown]
# ##DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_products['created_at'] = pd.to_datetime(df_products['created_at'], format='%m/%d/%y %H:%M')

# %%
df_products.dtypes
# Out:
# product_id               int64
# created_at      datetime64[ns]
# product_name            object
# dtype: object

# %% [markdown]
# ## #TABLE WEBSITE_PAGEVIEWS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/1DGSUZmY0fOSqLeghEnRQ8hd-M-TipYrZdQEAaF9xXPo/edit?gid=1050705122#gid=1050705122'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_website_pageviews = pd.read_csv(potter_csv_export_url)
df_website_pageviews
# Out:
#          website_pageview_id     created_at  website_session_id  \
# 0                          1   3/19/12 8:04                   1
# 1                          2   3/19/12 8:16                   2
# 2                          3   3/19/12 8:26                   3
# 3                          4   3/19/12 8:37                   4
# 4                          5   3/19/12 9:00                   5
# ...                      ...            ...                 ...
# 1048570              1048571  1/16/15 18:59              421952
# 1048571              1048572  1/16/15 19:01              421954
# 1048572              1048573  1/16/15 19:03              421952
# 1048573              1048574  1/16/15 19:03              421956
# 1048574              1048575  1/16/15 19:03              421952
#
#                       pageview_url
# 0                            /home
# 1                            /home
# 2                            /home
# 3                            /home
# ...

# %%
backup1=df_website_pageviews.copy()

# %%
df_website_pageviews.head()
# Out:
#    website_pageview_id    created_at  website_session_id pageview_url
# 0                    1  3/19/12 8:04                   1        /home
# 1                    2  3/19/12 8:16                   2        /home
# 2                    3  3/19/12 8:26                   3        /home
# 3                    4  3/19/12 8:37                   4        /home
# 4                    5  3/19/12 9:00                   5        /home

# %%
df_website_pageviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   website_pageview_id  1048575 non-null  int64
#  1   created_at           1048575 non-null  object
#  2   website_session_id   1048575 non-null  int64
#  3   pageview_url         1048575 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 32.0+ MB

# %% [markdown]
# tidak ditemukan data di column yg bernilai Null

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_website_pageviews.dtypes
# Out:
# website_pageview_id     int64
# created_at             object
# website_session_id      int64
# pageview_url           object
# dtype: object

# %% [markdown]
# tipe data di column created_at perlu diubah dr object ke datetime

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_website_pageviews:
    print(df_website_pageviews[column].value_counts())
# Out:
# website_pageview_id
# 1048575    1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 20         1
# 19         1
# 18         1
# 17         1
# 16         1
# Name: count, Length: 1048575, dtype: int64
# created_at
# 11/28/14 14:21    27
# 11/28/14 10:30    26
# 11/28/14 15:47    25
# 11/28/14 10:34    25
# 11/28/14 15:52    25
#                   ..
# 1/16/15 18:44      1
# 1/16/15 18:43      1
# 1/16/15 18:40      1
# 1/16/15 18:37      1
# 1/16/15 18:36      1
# Name: count, Length: 615935, dtype: int64
# website_session_id
# 230520    7
# 421928    7
# 20        7
# 230547    7
# 380508    7
#          ..
# 230518    1
# 8         1
# 9         1
# 10        1
# 11        1
# Name: count, Length: 421956, dtype: int64
# pageview_url
# /products                      230534
# /the-original-mr-fuzzy         145884
# /lander-2                      131170
# /home                          119993
# /cart                           82603
# ...

# %%
df_website_pageviews['website_pageview_id'].value_counts()
# Out:
# website_pageview_id
# 1048575    1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 20         1
# 19         1
# 18         1
# 17         1
# 16         1
# Name: count, Length: 1048575, dtype: int64

# %%
df_website_pageviews['created_at'].value_counts()
# Out:
# created_at
# 11/28/14 14:21    27
# 11/28/14 10:30    26
# 11/28/14 15:47    25
# 11/28/14 10:34    25
# 11/28/14 15:52    25
#                   ..
# 1/16/15 18:44      1
# 1/16/15 18:43      1
# 1/16/15 18:40      1
# 1/16/15 18:37      1
# 1/16/15 18:36      1
# Name: count, Length: 615935, dtype: int64

# %%
df_website_pageviews['website_session_id'].value_counts()
# Out:
# website_session_id
# 230520    7
# 421928    7
# 20        7
# 230547    7
# 380508    7
#          ..
# 230518    1
# 8         1
# 9         1
# 10        1
# 11        1
# Name: count, Length: 421956, dtype: int64

# %%
df_website_pageviews['pageview_url'].value_counts()
# Out:
# pageview_url
# /products                      230534
# /the-original-mr-fuzzy         145884
# /lander-2                      131170
# /home                          119993
# /cart                           82603
# /lander-3                       69969
# /shipping                       56124
# /lander-1                       47574
# /lander-5                       43865
# /billing-2                      41696
# /thank-you-for-your-order       27972
# /the-forever-love-bear          21410
# /the-birthday-sugar-panda       15690
# /lander-4                        9385
# /billing                         3617
# /the-hudson-river-mini-bear      1089
# Name: count, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table website_pageviews

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_website_pageviews['website_pageview_id'].duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Name: website_pageview_id, Length: 1048575, dtype: bool

# %%
df_website_pageviews['created_at'].duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573     True
# 1048574     True
# Name: created_at, Length: 1048575, dtype: bool

# %%
df_website_pageviews['website_session_id'].duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573    False
# 1048574     True
# Name: website_session_id, Length: 1048575, dtype: bool

# %%
df_website_pageviews['pageview_url'].duplicated()
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: pageview_url, Length: 1048575, dtype: bool

# %% [markdown]
# setelah dilakukan pengecekan dengan .duplicated, tdk ditemukan adanya data yg duplicate di semua column pada tabel website_pageviews

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_website_pageviews.isnull().sum()
# Out:
# website_pageview_id    0
# created_at             0
# website_session_id     0
# pageview_url           0
# dtype: int64

# %% [markdown]
# setelah dilakukan pengecekan missing value dengan .isnull().sum(), tidak ditemukan adanya data yg missing value di semua column pada tabel website_pageviews

# %% [markdown]
# ##DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_website_pageviews['created_at'] = pd.to_datetime(df_website_pageviews['created_at'], format='%m/%d/%y %H:%M')

# %%
df_website_pageviews.dtypes
# Out:
# website_pageview_id             int64
# created_at             datetime64[ns]
# website_session_id              int64
# pageview_url                   object
# dtype: object

# %%
df_website_pageviews.head()
# Out:
#    website_pageview_id          created_at  website_session_id pageview_url
# 0                    1 2012-03-19 08:04:00                   1        /home
# 1                    2 2012-03-19 08:16:00                   2        /home
# 2                    3 2012-03-19 08:26:00                   3        /home
# 3                    4 2012-03-19 08:37:00                   4        /home
# 4                    5 2012-03-19 09:00:00                   5        /home

# %% [markdown]
# ###conversi semua huruf di URL di column pegeview_url menjadi lowercase untuk memudahkan pencocokan string.

# %%
product_names = df_products['product_name'].str.lower().tolist()
df_website_pageviews["pageview_url_lower"] = df_website_pageviews["pageview_url"].str.lower()
df_website_pageviews["is_product_view"] = df_website_pageviews["pageview_url_lower"].apply(
    lambda url: any(product in url for product in product_names)
)

# %%
df_website_pageviews[["pageview_url", "is_product_view"]].head()
# Out:
#   pageview_url  is_product_view
# 0        /home            False
# 1        /home            False
# 2        /home            False
# 3        /home            False
# 4        /home            False

# %% [markdown]
# ## #TABLE ORDERS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/10YemLXrRqoTeo3CzjBbY2DddfHGrUD0Y8R4c9LU6q_8/edit?gid=1097446438#gid=1097446438'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_orders = pd.read_csv(potter_csv_export_url)
df_orders
# Out:
#        order_id     created_at  website_session_id  user_id  \
# 0             1  3/19/12 10:42                  20       20
# 1             2  3/19/12 19:27                 104      104
# 2             3   3/20/12 6:44                 147      147
# 3             4   3/20/12 9:41                 160      160
# 4             5  3/20/12 11:28                 177      177
# ...         ...            ...                 ...      ...
# 32308     32309   3/19/15 3:58              472795   394255
# 32309     32310   3/19/15 4:10              472798   394257
# 32310     32311   3/19/15 5:27              472809   394268
# 32311     32312   3/19/15 5:35              472814   394273
# 32312     32313   3/19/15 5:38              472818   386000
#
#        primary_product_id  items_purchased price_usd cogs_usd
# 0                       1                1     49,99    19,49
# 1                       1                1     49,99    19,49
# ...

# %%
backup1=df_orders.copy()

# %%
df_orders.head()
# Out:
#    order_id     created_at  website_session_id  user_id  primary_product_id  \
# 0         1  3/19/12 10:42                  20       20                   1
# 1         2  3/19/12 19:27                 104      104                   1
# 2         3   3/20/12 6:44                 147      147                   1
# 3         4   3/20/12 9:41                 160      160                   1
# 4         5  3/20/12 11:28                 177      177                   1
#
#    items_purchased price_usd cogs_usd
# 0                1     49,99    19,49
# 1                1     49,99    19,49
# 2                1     49,99    19,49
# 3                1     49,99    19,49
# 4                1     49,99    19,49

# %% [markdown]
# perlu dilakukan replace "," pada column price_usd dan cogs_usd dengan "."

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32313 entries, 0 to 32312
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            32313 non-null  int64
#  1   created_at          32313 non-null  object
#  2   website_session_id  32313 non-null  int64
#  3   user_id             32313 non-null  int64
#  4   primary_product_id  32313 non-null  int64
#  5   items_purchased     32313 non-null  int64
#  6   price_usd           32313 non-null  object
#  7   cogs_usd            32313 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# tidak ditemukan data di column yg bernilai Null

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_orders.dtypes
# Out:
# order_id               int64
# created_at            object
# website_session_id     int64
# user_id                int64
# primary_product_id     int64
# items_purchased        int64
# price_usd             object
# cogs_usd              object
# dtype: object

# %% [markdown]
# tipe data yg perlu diubah yaitu 1. column created_at perlu diubah dr object ke datetime 2. column price_usd dan cogs_usd perlu diubah dari object ke float dan me replace "," menjadi "."

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_orders:
    print(df_orders[column].value_counts())
# Out:
# order_id
# 32313    1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14       1
# 13       1
# 12       1
# 11       1
# 10       1
# Name: count, Length: 32313, dtype: int64
# created_at
# 12/15/14 15:28    4
# 9/17/14 15:03     3
# 7/16/14 11:15     3
# 11/28/14 14:18    3
# 11/28/14 9:48     3
#                  ..
# 1/23/14 14:02     1
# 1/23/14 13:52     1
# 1/23/14 13:39     1
# 1/23/14 13:21     1
# 1/23/14 17:10     1
# Name: count, Length: 31572, dtype: int64
# website_session_id
# 472818    1
# 20        1
# 104       1
# 147       1
# 160       1
#          ..
# 336       1
# 332       1
# 327       1
# 321       1
# 317       1
# Name: count, Length: 32313, dtype: int64
# user_id
# 68624     3
# 122640    3
# 276897    3
# 318660    3
# 275098    3
#          ..
# 161883    1
# 161875    1
# 161857    1
# 161853    1
# 161940    1
# Name: count, Length: 31696, dtype: int64
# primary_product_id
# 1    23861
# 2     4803
# 3     3068
# 4      581
# ...

# %%
df_orders['order_id'].value_counts()
# Out:
# order_id
# 32313    1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14       1
# 13       1
# 12       1
# 11       1
# 10       1
# Name: count, Length: 32313, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table orders

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_orders['order_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32308    False
# 32309    False
# 32310    False
# 32311    False
# 32312    False
# Name: order_id, Length: 32313, dtype: bool

# %%
df_orders['created_at'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32308    False
# 32309    False
# 32310    False
# 32311    False
# 32312    False
# Name: created_at, Length: 32313, dtype: bool

# %%
df_orders['website_session_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32308    False
# 32309    False
# 32310    False
# 32311    False
# 32312    False
# Name: website_session_id, Length: 32313, dtype: bool

# %%
df_orders['user_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32308    False
# 32309    False
# 32310    False
# 32311    False
# 32312    False
# Name: user_id, Length: 32313, dtype: bool

# %%
df_orders['primary_product_id'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32308     True
# 32309     True
# 32310     True
# 32311     True
# 32312     True
# Name: primary_product_id, Length: 32313, dtype: bool

# %%
df_orders['items_purchased'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32308     True
# 32309     True
# 32310     True
# 32311     True
# 32312     True
# Name: items_purchased, Length: 32313, dtype: bool

# %%
df_orders['price_usd'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32308     True
# 32309     True
# 32310     True
# 32311     True
# 32312     True
# Name: price_usd, Length: 32313, dtype: bool

# %%
df_orders['cogs_usd'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32308     True
# 32309     True
# 32310     True
# 32311     True
# 32312     True
# Name: cogs_usd, Length: 32313, dtype: bool

# %% [markdown]
# setelah dilakukan pengecekan dengan .duplicated, tdk ditemukan adanya data yg duplicate di semua column pada tabel orders

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_orders.isnull().sum()
# Out:
# order_id              0
# created_at            0
# website_session_id    0
# user_id               0
# primary_product_id    0
# items_purchased       0
# price_usd             0
# cogs_usd              0
# dtype: int64

# %% [markdown]
# setelah dilakukan pengecekan missing value dengan .isnull().sum(), tidak ditemukan adanya data yg missing value di semua column pada tabel orders

# %% [markdown]
# ##DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_orders['created_at'] = pd.to_datetime(df_orders['created_at'], format='%m/%d/%y %H:%M')

# %%
df_orders.dtypes
# Out:
# order_id                       int64
# created_at            datetime64[ns]
# website_session_id             int64
# user_id                        int64
# primary_product_id             int64
# items_purchased                int64
# price_usd                     object
# cogs_usd                      object
# dtype: object

# %%
df_orders.head()
# Out:
#    order_id          created_at  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:00                  20       20
# 1         2 2012-03-19 19:27:00                 104      104
# 2         3 2012-03-20 06:44:00                 147      147
# 3         4 2012-03-20 09:41:00                 160      160
# 4         5 2012-03-20 11:28:00                 177      177
#
#    primary_product_id  items_purchased price_usd cogs_usd
# 0                   1                1     49,99    19,49
# 1                   1                1     49,99    19,49
# 2                   1                1     49,99    19,49
# 3                   1                1     49,99    19,49
# 4                   1                1     49,99    19,49

# %% [markdown]
# ###merubah tipe data column price_usd serta cogs_usd dari object ke float dan me replace "," menjadi "."

# %%
df_orders['price_usd'] = df_orders['price_usd'].str.replace(',', '.').astype(float)
df_orders['cogs_usd'] = df_orders['cogs_usd'].str.replace(',', '.').astype(float)
print(df_orders[['price_usd', 'cogs_usd']].dtypes)
# Out:
# price_usd    float64
# cogs_usd     float64
# dtype: object

# %%
df_orders.dtypes
# Out:
# order_id                       int64
# created_at            datetime64[ns]
# website_session_id             int64
# user_id                        int64
# primary_product_id             int64
# items_purchased                int64
# price_usd                    float64
# cogs_usd                     float64
# dtype: object

# %%
df_orders.head()
# Out:
#    order_id          created_at  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:00                  20       20
# 1         2 2012-03-19 19:27:00                 104      104
# 2         3 2012-03-20 06:44:00                 147      147
# 3         4 2012-03-20 09:41:00                 160      160
# 4         5 2012-03-20 11:28:00                 177      177
#
#    primary_product_id  items_purchased  price_usd  cogs_usd
# 0                   1                1      49.99     19.49
# 1                   1                1      49.99     19.49
# 2                   1                1      49.99     19.49
# 3                   1                1      49.99     19.49
# 4                   1                1      49.99     19.49

# %% [markdown]
# ## #TABLE ORDER_ITEMS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/15E2af3_ABAN8vmQ2jext8fbr0H9MIHjl1suJhNE3rHI/edit?gid=1814474632#gid=1814474632'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_order_items = pd.read_csv(potter_csv_export_url)
df_order_items
# Out:
#        order_item_id     created_at  order_id  product_id  is_primary_item  \
# 0                  1  3/19/12 10:42         1           1                1
# 1                  2  3/19/12 19:27         2           1                1
# 2                  3   3/20/12 6:44         3           1                1
# 3                  4   3/20/12 9:41         4           1                1
# 4                  5  3/20/12 11:28         5           1                1
# ...              ...            ...       ...         ...              ...
# 40020          40021   3/19/15 4:10     32310           4                1
# 40021          40022   3/19/15 5:27     32311           2                1
# 40022          40023   3/19/15 5:27     32311           4                0
# 40023          40024   3/19/15 5:35     32312           4                1
# 40024          40025   3/19/15 5:38     32313           1                1
#
#       price_usd cogs_usd
# 0         49,99    19,49
# ...

# %%
backup1=df_order_items.copy()

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_order_items.dtypes
# Out:
# order_item_id       int64
# created_at         object
# order_id            int64
# product_id          int64
# is_primary_item     int64
# price_usd          object
# cogs_usd           object
# dtype: object

# %% [markdown]
# tipe data yg perlu diubah yaitu 1. column created_at perlu diubah dr object ke datetime 2. column is_primary_item diubah dr interger menjadi boolean 3. column price_usd dan cogs_usd perlu diubah dari object ke float dan me replace "," menjadi "."

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_order_items:
    print(df_order_items[column].value_counts())
# Out:
# order_item_id
# 40025    1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14       1
# 13       1
# 12       1
# 11       1
# 10       1
# Name: count, Length: 40025, dtype: int64
# created_at
# 3/18/14 11:50     6
# 12/15/14 15:28    6
# 12/1/14 10:36     6
# 12/1/14 13:12     5
# 7/16/14 11:15     5
#                  ..
# 1/1/14 10:40      1
# 1/1/14 10:38      1
# 1/1/14 10:10      1
# 1/1/14 9:57       1
# 1/1/14 19:05      1
# Name: count, Length: 31572, dtype: int64
# order_id
# 25800    2
# 13082    2
# 20213    2
# 25797    2
# 25796    2
#         ..
# 10112    1
# 10111    1
# 10110    1
# 10109    1
# 10124    1
# Name: count, Length: 32313, dtype: int64
# product_id
# 1    24226
# 2     5796
# 4     5018
# 3     4985
# Name: count, dtype: int64
# is_primary_item
# 1    32313
# 0     7712
# Name: count, dtype: int64
# price_usd
# 49,99    24226
# 59,99     5796
# 29,99     5018
# 45,99     4985
# Name: count, dtype: int64
# cogs_usd
# 19,49    24226
# ...

# %%
df_order_items['order_item_id'].value_counts()
# Out:
# order_item_id
# 40025    1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14       1
# 13       1
# 12       1
# 11       1
# 10       1
# Name: count, Length: 40025, dtype: int64

# %%
df_order_items['created_at'].value_counts()
# Out:
# created_at
# 3/18/14 11:50     6
# 12/15/14 15:28    6
# 12/1/14 10:36     6
# 12/1/14 13:12     5
# 7/16/14 11:15     5
#                  ..
# 1/1/14 10:40      1
# 1/1/14 10:38      1
# 1/1/14 10:10      1
# 1/1/14 9:57       1
# 1/1/14 19:05      1
# Name: count, Length: 31572, dtype: int64

# %%
df_order_items['order_id'].value_counts()
# Out:
# order_id
# 25800    2
# 13082    2
# 20213    2
# 25797    2
# 25796    2
#         ..
# 10112    1
# 10111    1
# 10110    1
# 10109    1
# 10124    1
# Name: count, Length: 32313, dtype: int64

# %%
df_order_items['product_id'].value_counts()
# Out:
# product_id
# 1    24226
# 2     5796
# 4     5018
# 3     4985
# Name: count, dtype: int64

# %%
df_order_items['is_primary_item'].value_counts()
# Out:
# is_primary_item
# 1    32313
# 0     7712
# Name: count, dtype: int64

# %%
df_order_items['price_usd'].value_counts()
# Out:
# price_usd
# 49,99    24226
# 59,99     5796
# 29,99     5018
# 45,99     4985
# Name: count, dtype: int64

# %%
df_order_items['cogs_usd'].value_counts()
# Out:
# cogs_usd
# 19,49    24226
# 22,49     5796
# 9,49      5018
# 14,49     4985
# Name: count, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table order_items

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_order_items['order_item_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40020    False
# 40021    False
# 40022    False
# 40023    False
# 40024    False
# Name: order_item_id, Length: 40025, dtype: bool

# %%
df_order_items['created_at'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40020    False
# 40021    False
# 40022     True
# 40023    False
# 40024    False
# Name: created_at, Length: 40025, dtype: bool

# %%
df_order_items['order_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40020    False
# 40021    False
# 40022     True
# 40023    False
# 40024    False
# Name: order_id, Length: 40025, dtype: bool

# %%
df_order_items['product_id'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 40020     True
# 40021     True
# 40022     True
# 40023     True
# 40024     True
# Name: product_id, Length: 40025, dtype: bool

# %%
df_order_items['is_primary_item'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 40020     True
# 40021     True
# 40022     True
# 40023     True
# 40024     True
# Name: is_primary_item, Length: 40025, dtype: bool

# %%
df_order_items['price_usd'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 40020     True
# 40021     True
# 40022     True
# 40023     True
# 40024     True
# Name: price_usd, Length: 40025, dtype: bool

# %%
df_order_items['cogs_usd'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 40020     True
# 40021     True
# 40022     True
# 40023     True
# 40024     True
# Name: cogs_usd, Length: 40025, dtype: bool

# %% [markdown]
# setelah dilakukan pengecekan dengan .duplicated, tdk ditemukan adanya data yg duplicate di semua column pada tabel order_items

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_order_items.isnull().sum()
# Out:
# order_item_id      0
# created_at         0
# order_id           0
# product_id         0
# is_primary_item    0
# price_usd          0
# cogs_usd           0
# dtype: int64

# %% [markdown]
# setelah dilakukan pengecekan missing value dengan .isnull().sum(), tidak ditemukan adanya data yg missing value di semua column pada tabel order_items

# %% [markdown]
# ##DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_order_items['created_at'] = pd.to_datetime(df_order_items['created_at'], format='%m/%d/%y %H:%M')

# %%
df_order_items.dtypes
# Out:
# order_item_id               int64
# created_at         datetime64[ns]
# order_id                    int64
# product_id                  int64
# is_primary_item             int64
# price_usd                  object
# cogs_usd                   object
# dtype: object

# %%
df_order_items.head()
# Out:
#    order_item_id          created_at  order_id  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:00         1           1                1
# 1              2 2012-03-19 19:27:00         2           1                1
# 2              3 2012-03-20 06:44:00         3           1                1
# 3              4 2012-03-20 09:41:00         4           1                1
# 4              5 2012-03-20 11:28:00         5           1                1
#
#   price_usd cogs_usd
# 0     49,99    19,49
# 1     49,99    19,49
# 2     49,99    19,49
# 3     49,99    19,49
# 4     49,99    19,49

# %% [markdown]
# ###merubah tipe data di column is_primary_item dr interger menjadi boolean

# %%
df_order_items['is_primary_item'] = df_order_items['is_primary_item'].astype(bool)

# %%
df_order_items.dtypes
# Out:
# order_item_id               int64
# created_at         datetime64[ns]
# order_id                    int64
# product_id                  int64
# is_primary_item              bool
# price_usd                  object
# cogs_usd                   object
# dtype: object

# %% [markdown]
# ###merubah tipe data column price_usd serta cogs_usd dari object ke float dan me replace "," menjadi "."

# %%
df_order_items['price_usd'] = df_order_items['price_usd'].str.replace(',', '.').astype(float)
df_order_items['cogs_usd'] = df_order_items['cogs_usd'].str.replace(',', '.').astype(float)
print(df_order_items[['price_usd', 'cogs_usd']].dtypes)
# Out:
# price_usd    float64
# cogs_usd     float64
# dtype: object

# %%
df_order_items.head()
# Out:
#    order_item_id          created_at  order_id  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:00         1           1             True
# 1              2 2012-03-19 19:27:00         2           1             True
# 2              3 2012-03-20 06:44:00         3           1             True
# 3              4 2012-03-20 09:41:00         4           1             True
# 4              5 2012-03-20 11:28:00         5           1             True
#
#    price_usd  cogs_usd
# 0      49.99     19.49
# 1      49.99     19.49
# 2      49.99     19.49
# 3      49.99     19.49
# 4      49.99     19.49

# %% [markdown]
# ## #TABLE ORDER_ITEM_REFUNDS

# %%
import pandas as pd

# %%
potter_url = 'https://docs.google.com/spreadsheets/d/1A2jHgdDj4FAGhu9JLS5tXEv80xNv4zKfYGpVMMd2qVQ/edit?gid=968260780#gid=968260780'
spreadsheet_id = potter_url.split('/')[-2]
gid = potter_url.split('gid=')[-1].split('#')[0]
potter_csv_export_url = f'https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={gid}'
df_order_item_refunds = pd.read_csv(potter_csv_export_url)
df_order_item_refunds
# Out:
#       order_item_refund_id     created_at  order_item_id  order_id  \
# 0                        1   4/6/12 11:32             57        57
# 1                        2   4/13/12 1:09             74        74
# 2                        3   4/15/12 7:03             71        71
# 3                        4  4/17/12 20:00            118       118
# 4                        5  4/22/12 20:53            116       116
# ...                    ...            ...            ...       ...
# 1726                  1727   3/30/15 9:37          39950     32255
# 1727                  1728  3/30/15 21:33          39671     32049
# 1728                  1729  3/31/15 19:59          39729     32090
# 1729                  1730    4/1/15 3:54          39717     32079
# 1730                  1731   4/1/15 18:11          39947     32252
#
#      refund_amount_usd
# 0                49,99
# 1                49,99
# 2                49,99
# 3                49,99
# 4                49,99
# ...

# %%
backup1=df_order_item_refunds.copy()

# %% [markdown]
# ##CEK TIPE DATA

# %%
df_order_item_refunds.dtypes
# Out:
# order_item_refund_id     int64
# created_at              object
# order_item_id            int64
# order_id                 int64
# refund_amount_usd       object
# dtype: object

# %% [markdown]
# tipe data yg perlu diubah yaitu 1. column created_at perlu diubah dr object ke datetime 2. column refund_amount_usd perlu diubah dari object ke float dan me replace "," menjadi "."

# %% [markdown]
# ##CEK TYPO

# %%
for column in df_order_item_refunds:
    print(df_order_item_refunds[column].value_counts())
# Out:
# order_item_refund_id
# 1731    1
# 1       1
# 2       1
# 1715    1
# 1714    1
#        ..
# 8       1
# 7       1
# 6       1
# 5       1
# 4       1
# Name: count, Length: 1731, dtype: int64
# created_at
# 9/5/14 2:37      2
# 9/7/14 7:47      2
# 9/19/14 21:54    1
# 9/19/14 18:29    1
# 9/19/14 15:08    1
#                 ..
# 2/14/14 9:38     1
# 2/14/14 9:10     1
# 2/14/14 8:29     1
# 2/12/14 3:28     1
# 2/23/14 12:02    1
# Name: count, Length: 1729, dtype: int64
# order_item_id
# 39947    1
# 57       1
# 74       1
# 39813    1
# 39172    1
#         ..
# 191      1
# 186      1
# 147      1
# 116      1
# 118      1
# Name: count, Length: 1731, dtype: int64
# order_id
# 23321    2
# 24472    2
# 9324     2
# 27061    2
# 28802    2
#         ..
# 11124    1
# 11157    1
# 10904    1
# 11084    1
# 11265    1
# Name: count, Length: 1723, dtype: int64
# refund_amount_usd
# 49,99    1237
# 45,99     301
# 59,99     129
# 29,99      64
# Name: count, dtype: int64

# %% [markdown]
# setelah pengecekan dengan .value_counts() tdk ditemukan adanya TYPO di semua column pada table order_item_refunds

# %% [markdown]
# ##CEK DUPLICATE

# %%
df_order_item_refunds['order_item_refund_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1726    False
# 1727    False
# 1728    False
# 1729    False
# 1730    False
# Name: order_item_refund_id, Length: 1731, dtype: bool

# %%
df_order_item_refunds['created_at'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1726    False
# 1727    False
# 1728    False
# 1729    False
# 1730    False
# Name: created_at, Length: 1731, dtype: bool

# %%
df_order_item_refunds['order_item_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1726    False
# 1727    False
# 1728    False
# 1729    False
# 1730    False
# Name: order_item_id, Length: 1731, dtype: bool

# %%
df_order_item_refunds['order_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1726    False
# 1727    False
# 1728    False
# 1729    False
# 1730    False
# Name: order_id, Length: 1731, dtype: bool

# %%
df_order_item_refunds['refund_amount_usd'].duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1726     True
# 1727     True
# 1728     True
# 1729     True
# 1730     True
# Name: refund_amount_usd, Length: 1731, dtype: bool

# %% [markdown]
# setelah dilakukan pengecekan dengan .duplicated, tdk ditemukan adanya data yg duplicate di semua column pada tabel order_item_refunds

# %% [markdown]
# ##CEK MISSING VALUE

# %%
df_order_item_refunds.isnull().sum()
# Out:
# order_item_refund_id    0
# created_at              0
# order_item_id           0
# order_id                0
# refund_amount_usd       0
# dtype: int64

# %% [markdown]
# setelah dilakukan pengecekan missing value dengan .isnull().sum(), tidak ditemukan adanya data yg missing value di semua column pada tabel order_item_refunds

# %% [markdown]
# ##DATA CLEANING AND PREPARATION

# %% [markdown]
# ###merubah tipe data di column created_at dari object menjadi datetime

# %%
df_order_item_refunds['created_at'] = pd.to_datetime(df_order_item_refunds['created_at'], format='%m/%d/%y %H:%M')

# %%
df_order_item_refunds.dtypes
# Out:
# order_item_refund_id             int64
# created_at              datetime64[ns]
# order_item_id                    int64
# order_id                         int64
# refund_amount_usd               object
# dtype: object

# %%
df_order_item_refunds.head()
# Out:
#    order_item_refund_id          created_at  order_item_id  order_id  \
# 0                     1 2012-04-06 11:32:00             57        57
# 1                     2 2012-04-13 01:09:00             74        74
# 2                     3 2012-04-15 07:03:00             71        71
# 3                     4 2012-04-17 20:00:00            118       118
# 4                     5 2012-04-22 20:53:00            116       116
#
#   refund_amount_usd
# 0             49,99
# 1             49,99
# 2             49,99
# 3             49,99
# 4             49,99

# %% [markdown]
# ###merubah tipe data di column refund_amount_usd perlu dari object ke float dan me replace "," menjadi "."

# %%
df_order_item_refunds['refund_amount_usd'] = df_order_item_refunds['refund_amount_usd'].str.replace(',', '.').astype(float)

# %%
df_order_item_refunds.dtypes
# Out:
# order_item_refund_id             int64
# created_at              datetime64[ns]
# order_item_id                    int64
# order_id                         int64
# refund_amount_usd              float64
# dtype: object

# %%
df_order_item_refunds.head()
# Out:
#    order_item_refund_id          created_at  order_item_id  order_id  \
# 0                     1 2012-04-06 11:32:00             57        57
# 1                     2 2012-04-13 01:09:00             74        74
# 2                     3 2012-04-15 07:03:00             71        71
# 3                     4 2012-04-17 20:00:00            118       118
# 4                     5 2012-04-22 20:53:00            116       116
#
#    refund_amount_usd
# 0              49.99
# 1              49.99
# 2              49.99
# 3              49.99
# 4              49.99

# %% [markdown]
# ##MERGED DATA (orders and order_items)

# %%
df_merged = pd.merge(df_orders, df_order_items, on='order_id', how='inner')
display(df_merged.head())
# Out:
#    order_id        created_at_x  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:00                  20       20
# 1         2 2012-03-19 19:27:00                 104      104
# 2         3 2012-03-20 06:44:00                 147      147
# 3         4 2012-03-20 09:41:00                 160      160
# 4         5 2012-03-20 11:28:00                 177      177
#
#    primary_product_id  items_purchased  price_usd_x  cogs_usd_x  \
# 0                   1                1        49.99       19.49
# 1                   1                1        49.99       19.49
# 2                   1                1        49.99       19.49
# 3                   1                1        49.99       19.49
# 4                   1                1        49.99       19.49
#
#    order_item_id        created_at_y  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:00           1             True
# 1              2 2012-03-19 19:27:00           1             True
# ...

# %%
backup=df_merged.copy()

# %%
# Make a copy of the clean data for segmentation
df_segmentation = df_merged.copy()
df_segmentation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40025 entries, 0 to 40024
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            40025 non-null  int64
#  1   created_at_x        40025 non-null  datetime64[ns]
#  2   website_session_id  40025 non-null  int64
#  3   user_id             40025 non-null  int64
#  4   primary_product_id  40025 non-null  int64
#  5   items_purchased     40025 non-null  int64
#  6   price_usd_x         40025 non-null  float64
#  7   cogs_usd_x          40025 non-null  float64
#  8   order_item_id       40025 non-null  int64
#  9   created_at_y        40025 non-null  datetime64[ns]
#  10  product_id          40025 non-null  int64
#  11  is_primary_item     40025 non-null  bool
#  12  price_usd_y         40025 non-null  float64
#  13  cogs_usd_y          40025 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(4), int64(7)
# ...

# %% [markdown]
# #KMeans Segmentation

# %% [markdown]
# ###A. Data Preprocessing

# %%
df_segmentation = df_merged.copy()
df_segmentation_feature = df_segmentation[['price_usd_x', 'cogs_usd_x']]
display(df_segmentation_feature.head())
# Out:
#    price_usd_x  cogs_usd_x
# 0        49.99       19.49
# 1        49.99       19.49
# 2        49.99       19.49
# 3        49.99       19.49
# 4        49.99       19.49

# %% [markdown]
# ####A.1. Distribution Check

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of amt_nonfraud_trx_L6M, count_nonfraud_trx_L6M, credit_limit, and DTI
plt.figure(figsize=(10,6))

plt.subplot(2, 2, 1)
sns.histplot(df_segmentation['price_usd_x'], kde=True)
plt.title('Distribution of price_usd_x')

plt.subplot(2, 2, 2)
sns.histplot(df_segmentation['cogs_usd_x'], kde=True)
plt.title('Distribution of cogs_usd_x')

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the distribution plots for price_usd_x and cogs_usd_x, it appears that both variables have a multi-modal distribution, indicated by several peaks in the histograms. This suggests that there are distinct price points and corresponding cost of goods sold (COGS) values for different products or product categories. The distributions are not perfectly normal, implying that sales are not uniformly distributed across all price or COGS ranges. Further analysis might be needed to understand why there are specific price/COGS clusters and what products contribute to them.

# %% [markdown]
# ####A.2. Applying Scaling Method

# %%
from scipy.stats import shapiro, skew

def determine_scaler(data, column_name):
    # Perform Shapiro-Wilk test for normality and calculate skewness
    stat, p_value = shapiro(data[column_name])
    skewness = skew(data[column_name])

    # Print results for debugging
    print(f"{column_name} - Shapiro-Wilk Test: Statistic={stat}, p-value={p_value}")
    print(f"{column_name} - Skewness: {skewness}")

    # Determine which scaler to use
    if p_value > 0.05 and -1 <= skewness <= 1:
        scaler = "StandardScaler"
    elif p_value < 0.05 and -1 <= skewness <= 1:
        scaler = "MinMaxScaler"
    elif p_value < 0.05 and (skewness < -1 or skewness > 1):
        scaler = "RobustScaler"
    else:
        scaler = "RobustScaler"

    return scaler

# Example usage with the dataframe 'df_segmentation'
price_usd_x_scaler = determine_scaler(df_segmentation, 'price_usd_x')
cogs_usd_x_scaler = determine_scaler(df_segmentation, 'cogs_usd_x')

print(f"Recommended Scaler for price usd x: {price_usd_x_scaler}")
print(f"Recommended Scaler for cogs usd x: {cogs_usd_x_scaler}")
# Out:
# price_usd_x - Shapiro-Wilk Test: Statistic=0.8232992262066761, p-value=1.956698134286812e-106
# price_usd_x - Skewness: 0.7179954310843704
# cogs_usd_x - Shapiro-Wilk Test: Statistic=0.8619679099483271, p-value=4.871298617800645e-100
# cogs_usd_x - Skewness: 0.7867429668295816
# Recommended Scaler for price usd x: MinMaxScaler
# Recommended Scaler for cogs usd x: MinMaxScaler
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 40025.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ####A.3. Normalization using Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df_segmentation_feature)
df_scaled = pd.DataFrame(df_scaled, columns=df_segmentation_feature.columns)
display(df_scaled.head())
# Out:
#    price_usd_x  cogs_usd_x
# 0     0.250031    0.307787
# 1     0.250031    0.307787
# 2     0.250031    0.307787
# 3     0.250031    0.307787
# 4     0.250031    0.307787

# %% [markdown]
# ###B. Determine Cluster Number

# %% [markdown]
# ####Elbow Method

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

distortions = []
K = range(2,6)
for k in K:
    kmeanModel = KMeans(n_clusters=k, random_state=1000, n_init='auto')
    kmeanModel.fit(df_scaled)
    distortions.append(kmeanModel.inertia_)

plt.figure(figsize=(13,7))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('The Elbow Method showing the optimal k')
plt.show()
print(distortions)
# Out:
# [867.1082288477124, 420.55970787123084, 277.47184492116395, 172.1396149771961]

# %% [markdown]
# Based on the elbow method plot and the 'distortions' values, the optimal number of clusters (k) appears to be 3. There is a significant drop in inertia when moving from 2 to 3 clusters, after which the rate of decrease in inertia starts to slow down. This point, often referred to as the 'elbow,' suggests that adding more clusters beyond 3 provides diminishing returns in reducing the within-cluster sum of squares, meaning that 3 clusters effectively capture the underlying structure in the data.

# %% [markdown]
# ####Silhouette Analysis

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import SilhouetteVisualizer
import numpy as np
import matplotlib.pyplot as plt

K_range = range(2,6)
banyak_K = len(K_range)
n_baris = int(np.ceil(banyak_K/2))

fig, ax = plt.subplots(n_baris, 2, figsize=(15,30))

for index, K in enumerate(K_range):
  kmeanModel = KMeans(n_clusters=K, random_state=1000, n_init='auto')
  sil = SilhouetteVisualizer(kmeanModel, is_fitted=False, ax=ax.flatten()[index])
  sil.fit(df_scaled)
  sil.finalize()
  print(f"For k={K}, the average silhouette score is {sil.silhouette_score_}")
# Out:
# For k=2, the average silhouette score is 0.7724261079207367
# For k=3, the average silhouette score is 0.764818112870933
# For k=4, the average silhouette score is 0.8140998077226397
# For k=5, the average silhouette score is 0.8122793557788573

# %% [markdown]
# Based on the Silhouette Analysis, the highest average silhouette score is 0.8140998077226397 for k=4. This indicates that a clustering with 4 clusters results in the most well-defined and separated clusters among the tested values. While the Elbow Method suggested k=3, the Silhouette score for k=4 is higher, implying that 4 clusters might be a better choice for this dataset in terms of cluster cohesion and separation. The score for k=5 is also high, but slightly lower than k=4, suggesting that adding a fifth cluster does not significantly improve the clustering quality and might introduce more complexity.

# %% [markdown]
# ###C. K-Means Clustering Modelling

# %% [markdown]
# #### #C.1. K-Means Clustering Modelling with 3 Clusters

# %%
df3_norm = df_scaled.copy()
df3 = df_segmentation.copy()

from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=3, random_state=1000, n_init='auto')
cluster_model.fit(df3_norm)

df3_norm['clusters'] = cluster_model.labels_

cluster_labels_series = pd.Series(cluster_model.labels_, index=df_segmentation_feature.index)

df3['clusters'] = cluster_labels_series

df3['clusters'] = df3['clusters'].fillna(-1).astype(int)

# %%
from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=3, random_state=1000, n_init='auto')
cluster_model.fit(df3_norm)
# Out:
# KMeans(n_clusters=3, random_state=1000)

# %%
df3_norm['clusters'] = cluster_model.labels_

# Create a Series of cluster labels with the original index from the filtered feature set
cluster_labels_series = pd.Series(cluster_model.labels_, index=df_segmentation_feature.index)

df3['clusters'] = cluster_labels_series

# Fill NaN values (for rows excluded from clustering) with -1 and convert to integer
df3['clusters'] = df3['clusters'].fillna(-1).astype(int)

# %%
df3.head()
# Out:
#    order_id        created_at_x  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:00                  20       20
# 1         2 2012-03-19 19:27:00                 104      104
# 2         3 2012-03-20 06:44:00                 147      147
# 3         4 2012-03-20 09:41:00                 160      160
# 4         5 2012-03-20 11:28:00                 177      177
#
#    primary_product_id  items_purchased  price_usd_x  cogs_usd_x  \
# 0                   1                1        49.99       19.49
# 1                   1                1        49.99       19.49
# 2                   1                1        49.99       19.49
# 3                   1                1        49.99       19.49
# 4                   1                1        49.99       19.49
#
#    order_item_id        created_at_y  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:00           1             True
# 1              2 2012-03-19 19:27:00           1             True
# ...

# %% [markdown]
# #### # #C.1.a. Cluster Distribution in price_usd_x, cogs_usd_x

# %%
sns.boxplot (data = df3, x ='clusters' , y ='price_usd_x', color='orange')
# Out:
# <Axes: xlabel='clusters', ylabel='price_usd_x'>

# %%
sns.boxplot (data = df3, x ='clusters' , y ='cogs_usd_x', color='lightgreen')
# Out:
# <Axes: xlabel='clusters', ylabel='cogs_usd_x'>

# %% [markdown]
# #### # #C.1.b. Cluster Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 6))


# Plot 1: price_usd_x vs cogs_usd_x
sns.scatterplot(
    data=df3,
    x='price_usd_x',
    y='cogs_usd_x',
    hue='clusters',
    palette='viridis',
    s=100, # Marker size
    alpha=0.7 # Transparency
)
plt.title('Price USD (x) vs COGS USD (x) by Cluster')
plt.xlabel('Price USD (x)')
plt.ylabel('COGS USD (x)')
plt.legend(title='Cluster')
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### #C.2. K-Means Clustering Modelling with 4 Clusters

# %%
df4_norm = df_scaled.copy()
df4 = df_segmentation.copy()

from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=4, random_state=1000, n_init='auto')
cluster_model.fit(df4_norm)

df4_norm['clusters'] = cluster_model.labels_

cluster_labels_series = pd.Series(cluster_model.labels_, index=df_segmentation_feature.index)

df4['clusters'] = cluster_labels_series

df4['clusters'] = df4['clusters'].fillna(-1).astype(int)

# %%
from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=4, random_state=1000, n_init='auto')
cluster_model.fit(df4_norm)
# Out:
# KMeans(n_clusters=4, random_state=1000)

# %% [markdown]
# #### # #C.2.a. Cluster Distribution in price_usd_x, cogs_usd_x

# %%
sns.boxplot (data = df4, x ='clusters' , y ='price_usd_x', color='orange')
# Out:
# <Axes: xlabel='clusters', ylabel='price_usd_x'>

# %%
sns.boxplot (data = df4, x ='clusters' , y ='cogs_usd_x', color='lightgreen')
# Out:
# <Axes: xlabel='clusters', ylabel='cogs_usd_x'>

# %% [markdown]
# #### # #C.2.b. Cluster Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 6))


# Plot 1: price_usd_x vs cogs_usd_x
sns.scatterplot(
    data=df4,
    x='price_usd_x',
    y='cogs_usd_x',
    hue='clusters',
    palette='viridis',
    s=100, # Marker size
    alpha=0.7 # Transparency
)
plt.title('Price USD (x) vs COGS USD (x) by Cluster')
plt.xlabel('Price USD (x)')
plt.ylabel('COGS USD (x)')
plt.legend(title='Cluster')
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# Comparing the cluster visualizations for df3 (3 clusters) and df4 (4 clusters):
#
# For 3 Clusters (df3):
#
# The visualization likely shows three distinct groups, generally separating products into low, medium, and high price/COGS categories. For instance, one cluster might encompass lower-priced, lower-cost items, another for mid-range, and a third for higher-end products.
# This segmentation provides a broad overview, but some overlap or less distinct boundaries might exist, especially for products that fall between these general categories.
# For 4 Clusters (df4):
#
# With 4 clusters, the segmentation appears more refined, aligning with the higher silhouette score for k=4.
# It's probable that one of the broader clusters from the 3-cluster model has been further subdivided. For example, the 'low' or 'medium' category might have split into two more specific groups (e.g., 'very low' and 'low', or 'lower-mid' and 'upper-mid').
# This increased granularity provides a clearer distinction between product types based on their price and cost of goods sold. Each of the four clusters would represent a more homogeneous group of products with similar price and COGS characteristics, leading to better-defined and more cohesive segments.
#
# ---> Overall Insight: The 4-cluster model offers a more nuanced and accurate representation of the underlying structure in the data, as evidenced by its higher silhouette score and the improved visual separation in the scatter plot. It allows for a more detailed understanding of product categories based on their pricing and cost structure, which can be valuable for targeted marketing, pricing strategies, and inventory management.

# %% [markdown]
# ### D. Cluster Interpretation

# %%
df4.head()
# Out:
#    order_id        created_at_x  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:00                  20       20
# 1         2 2012-03-19 19:27:00                 104      104
# 2         3 2012-03-20 06:44:00                 147      147
# 3         4 2012-03-20 09:41:00                 160      160
# 4         5 2012-03-20 11:28:00                 177      177
#
#    primary_product_id  items_purchased  price_usd_x  cogs_usd_x  \
# 0                   1                1        49.99       19.49
# 1                   1                1        49.99       19.49
# 2                   1                1        49.99       19.49
# 3                   1                1        49.99       19.49
# 4                   1                1        49.99       19.49
#
#    order_item_id        created_at_y  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:00           1             True
# 1              2 2012-03-19 19:27:00           1             True
# ...

# %%
df4.groupby(['price_usd_x', 'cogs_usd_x']).agg(['count','mean','min','max','median'])
# Out:
#                        order_id                                       \
#                           count          mean    min    max   median
# price_usd_x cogs_usd_x
# 29.99       9.49            534  28564.694757  25125  32312  28328.5
# 45.99       14.49          2039  20244.209416   9417  32307  20110.0
# 49.99       19.49         18104  13111.204319      1  32313  10775.5
# 59.99       22.49          3924  16554.332314   2662  32303  15761.0
# 75.98       23.98          1324  22037.045317  11150  32304  22068.5
# 79.98       28.98          6284  21442.440802  11149  32298  21297.0
# 89.98       31.98          1360  22144.841176  11148  32311  22517.0
# 95.98       33.98          4072  20949.016208   9406  32299  20912.0
# 105.98      36.98           496  20627.592742   9628  32041  20142.0
# 109.98      41.98          1888  19531.994703   7300  32289  19303.0
#
#                        created_at_x                                \
# ...

# %% [markdown]
# output provides detailed insights into the characteristics of each cluster based on price and cost of goods sold:
#
# Clear Segmentation: The output shows that each unique combination of price_usd_x and cogs_usd_x is assigned to a specific cluster (0, 1, 2, or 3). This indicates that the K-Means algorithm effectively grouped products with similar pricing and cost structures.
#
# Cluster 0: This cluster appears to represent products with the lowest price points and COGS, such as those around $29.99 (COGS $9.49), $45.99 (COGS $14.49), $49.99 (COGS $19.49), and $59.99 (COGS $22.49). This suggests a segment of entry-level or budget-friendly products.
#
# Cluster 1: This cluster includes products with mid-range prices and COGS, specifically around $75.98 (COGS $23.98) and $79.98 (COGS $28.98). These could be standard or popular products.
#
# Cluster 2: This segment groups products with higher mid-range prices and COGS, like those around $89.98 (COGS $31.98) and $95.98 (COGS $33.98).
#
# Cluster 3: This cluster contains products with the highest price points and COGS, such as $105.98 (COGS $36.98) and $109.98 (COGS $41.98). This likely represents premium or high-value products.
#
# In summary, the 4-cluster model successfully segmented the products into distinct tiers based on their price and associated cost, which can be invaluable for strategic decision-making regarding pricing, marketing, and inventory management for each product segment.

# %%
cluster_stats_df4 = df4.groupby('clusters')[['price_usd_x', 'cogs_usd_x']].agg(
    ['count', 'mean', 'median', 'min', 'max', 'std']
)
display(cluster_stats_df4)
# Out:
#          price_usd_x                                               cogs_usd_x  \
#                count        mean  median     min     max       std      count
# clusters
# 0              24601   50.819397   49.99   29.99   59.99  5.027166      24601
# 1               7608   79.283891   79.98   75.98   79.98  1.516632       7608
# 2               5432   94.477791   95.98   89.98   95.98  2.599590       5432
# 3               2384  109.147785  109.98  105.98  109.98  1.624002       2384
#
#
#                mean median    min    max       std
# clusters
# 0         19.337039  19.49   9.49  22.49  2.378045
# 1         28.109863  28.98  23.98  28.98  1.895790
# 2         33.479264  33.98  31.98  33.98  0.866530
# 3         40.939732  41.98  36.98  41.98  2.030003

# %% [markdown]
# summary of each cluster based on the price_usd_x and cogs_usd_x statistics:
#
# ---> Cluster 0 (Entry-Level/Budget-Friendly Products):
#
# Count: 24601 items
# Average Price: $50.82
# Average COGS: $19.34
# Price Range: $29.99 to $59.99
# COGS Range: $9.49 to $22.49
# This cluster represents the largest segment, characterized by the lowest prices and corresponding costs, indicating products that are likely entry-level or budget-friendly options.
#
# ---> Cluster 1 (Standard/Mid-Range Products):
#
# Count: 7608 items
# Average Price: $79.28
# Average COGS: $28.11
# Price Range: $75.98 to $79.98
# COGS Range: $23.98 to $28.98
# This cluster includes products with mid-range prices and costs, suggesting standard or popular items that offer a balance between price and value.
#
# ---> Cluster 2 (Higher Mid-Range Products):
#
# Count: 5432 items
# Average Price: $94.48
# Average COGS: $33.48
# Price Range: $89.98 to $95.98
# COGS Range: $31.98 to $33.98
# This cluster comprises products at a higher mid-range price point with elevated costs, indicating more specialized or higher-quality standard offerings.
#
# ---> Cluster 3 (Premium/High-Value Products):
#
# Count: 2384 items
# Average Price: $109.28
# Average COGS: $41.69
# Price Range: $105.98 to $109.98
# COGS Range: $36.98 to $41.98
# This cluster represents the smallest segment, featuring the highest prices and COGS, which points to premium or high-value products.
# These summaries provide a clear distinction between the product segments, allowing for tailored strategies in marketing, pricing, and inventory management for each group.

# %% [markdown]
# Based on the detailed characteristics of each of the 4 product clusters (Entry-Level, Standard/Mid-Range, Higher Mid-Range, and Premium/High-Value), formulated actionable recommendations tailored to maximize engagement, sales, and profitability for each segment :
#
# ---> Recommendations for Entry-Level/Budget-Friendly Products (Cluster 0): Provide tailored recommendations for marketing strategies, pricing adjustments, and product development/inventory management for products in Cluster 0, which are characterized by the lowest prices and COGS.
#
# ---> Recommendations for Standard/Mid-Range Products (Cluster 1): Provide tailored recommendations for marketing strategies, pricing adjustments, and product development/inventory management for products in Cluster 1, which have mid-range prices and COGS.
#
# ---> Recommendations for Higher Mid-Range Products (Cluster 2): Provide tailored recommendations for marketing strategies, pricing adjustments, and product development/inventory management for products in Cluster 2, which are at a higher mid-range price point with elevated costs.
#
# ---> Recommendations for Premium/High-Value Products (Cluster 3): Provide tailored recommendations for marketing strategies, pricing adjustments, and product development/inventory management for products in Cluster 3, which represent the highest prices and COGS.
# Final Task: Summarize the actionable recommendations for all four product clusters, highlighting how these strategies can maximize engagement, sales, and profitability for each segment.

# %% [markdown]
# ### Recommendations for Entry-Level/Budget-Friendly Products (Cluster 0)
#
# Cluster 0 is characterized by the lowest prices (average $50.82) and COGS (average $19.34), representing entry-level or budget-friendly products. The strategies should focus on maximizing volume and customer accessibility.
#
# #### 1. Marketing Strategies:
# *   **Value-Oriented Messaging:** Emphasize affordability, cost-effectiveness, and the best value for money. Use taglines like "Smart Buy," "Affordable Quality," or "Everyday Essentials."
# *   **Targeted Digital Advertising:** Utilize platforms with broad reach and cost-effective ad options (e.g., social media ads, search engine marketing for value-driven keywords) to reach budget-conscious consumers.
# *   **Partnerships and Bundles:** Collaborate with complementary budget-friendly brands or create bundles with other Cluster 0 products to increase perceived value and average order value.
# *   **User-Generated Content:** Encourage reviews and testimonials from satisfied customers who appreciate the product's value, leveraging social proof.
#
# #### 2. Pricing Adjustments:
# *   **Competitive Pricing:** Continuously monitor competitors' pricing for similar entry-level products to ensure pricing remains highly competitive. Consider price matching or slightly undercutting if feasible.
# *   **Promotions and Discounts:** Implement frequent promotions such as "Buy One Get One Free" (BOGO), percentage-off sales, or introductory discounts to drive impulse purchases and attract new customers.
# *   **Subscription Models:** For consumable or regularly needed products, consider a subscription model that offers a slight discount for recurring purchases, ensuring customer loyalty and predictable revenue.
# *   **Tiered Pricing:** Offer basic versions of products at the lowest price point, with slightly higher-priced options that include minor upgrades, allowing customers to choose based on their budget.
#
# #### 3. Product Development and Inventory Management:
# *   **Cost-Efficient Production:** Focus on maintaining low manufacturing and sourcing costs. Explore economies of scale and efficient supply chain management to keep COGS low.
# *   **Efficient Inventory Management:** Implement just-in-time (JIT) inventory systems to minimize holding costs and reduce the risk of obsolescence, given the high volume nature of these products.
# *   **Product Simplification:** Streamline product features to focus on core functionalities that provide maximum value at the lowest cost.
# *   **Expand Basic Product Lines:** Introduce new variations or colors of existing popular entry-level products without significantly increasing costs, catering to diverse preferences within the budget segment.
# *   **Cross-Selling with Higher Clusters (Carefully):** While the focus is on affordability, consider subtle cross-selling opportunities for higher-margin products (e.g., "Customers who bought this also bought...") but do not push premium products too aggressively.

# %% [markdown]
# ### Recommendations for Standard/Mid-Range Products (Cluster 1)
#
# Cluster 1 products are characterized by mid-range prices (average $79.28) and COGS (average $28.11). The strategies for this segment should focus on perceived quality, competitive differentiation, and expanding market share.
#
# #### 1. Marketing Strategies:
# *   **Quality and Value Proposition:** Highlight the balance between quality and price. Emphasize features, durability, and customer satisfaction. Messaging should focus on "Best Value for Money" without explicitly being "cheap."
# *   **Benefit-Oriented Advertising:** Showcase how these products solve common customer problems or enhance their lifestyle. Use visuals that convey reliability and satisfaction.
# *   **Customer Testimonials and Reviews:** Actively collect and promote positive customer reviews and testimonials, as mid-range buyers often rely on peer validation.
# *   **Content Marketing:** Create blog posts, comparison guides, or videos that demonstrate the product's advantages over both cheaper and slightly more expensive alternatives.
# *   **Targeted Ads (Demographics):** Use demographic and interest-based targeting in digital ads to reach consumers who are looking for reliable products at a reasonable price point.
#
# #### 2. Pricing Adjustments:
# *   **Value Pricing:** Position products as offering superior value compared to competitors. Avoid significant price drops that might devalue the brand, instead focusing on perceived benefits.
# *   **Strategic Bundling:** Offer bundles with complementary accessories or services that add value rather than just reducing price. For example, a product plus a warranty or a starter kit.
# *   **Loyalty Programs:** Implement loyalty programs or repeat purchase discounts to retain customers who are satisfied with the value and quality of these products.
# *   **Seasonal Promotions:** Run seasonal or holiday promotions that offer a compelling reason to buy, but maintain healthy margins.
#
# #### 3. Product Development and Inventory Management:
# *   **Feature Enhancement:** Continuously evaluate and add desirable features that differentiate these products from entry-level options, without pushing them into the premium category.
# *   **Quality Control:** Maintain high-quality standards to build trust and reduce returns, which is crucial for customers seeking reliable mid-range products.
# *   **Optimized Inventory Levels:** Balance inventory to meet consistent demand without overstocking, utilizing sales forecasts and historical data. Avoid stockouts to prevent customers from looking at competitors.
# *   **Customer Feedback Integration:** Use feedback from this large customer base to drive iterative product improvements and ensure products remain aligned with market expectations.
# *   **Cross-Selling with Higher Clusters (Upselling):** Leverage satisfied customers in this segment for soft upselling to premium products (Cluster 3) by highlighting advanced features or superior benefits.

# %% [markdown]
# ### Recommendations for Higher Mid-Range Products (Cluster 2)
#
# Cluster 2 products are positioned at a higher mid-range price point (average $94.48) with elevated COGS (average $33.48). Strategies for this segment should focus on emphasizing advanced features, superior quality, and a premium experience without reaching the top-tier luxury.
#
# #### 1. Marketing Strategies:
# *   **Feature-Rich Communication:** Highlight advanced functionalities, superior materials, and unique benefits that justify the higher price point. Use detailed product descriptions and demonstrations.
# *   **Premium Branding:** Position these products as a step up from standard offerings. Use sophisticated visuals and messaging that appeal to discerning customers willing to pay more for enhanced quality and performance.
# *   **Influencer Marketing and Expert Reviews:** Partner with industry experts or relevant influencers who can attest to the product's quality and benefits, building credibility and trust.
# *   **Targeted Advertising (Lifestyle-Oriented):** Focus on digital advertising that targets demographics interested in quality, specific hobbies, or a certain lifestyle that aligns with the product's value proposition.
# *   **Comparative Marketing:** Gently compare these products to both lower-tier options (showing clear advantages) and higher-tier premium products (highlighting comparable features at a better value).
#
# #### 2. Pricing Adjustments:
# *   **Premium Pricing Strategy:** Maintain a price that reflects the enhanced value and quality. Avoid frequent or deep discounts, which can devalue the brand.
# *   **Value-Added Services:** Offer extended warranties, premium customer support, or personalized setup services as part of the purchase to justify the price point.
# *   **Bundle with Exclusives:** Create bundles that include exclusive or limited-edition accessories, enhancing the perceived value and uniqueness of the offering.
# *   **Financing Options:** Provide flexible payment or financing options to make the higher price more accessible to a broader range of customers.
#
# #### 3. Product Development and Inventory Management:
# *   **Innovation and Differentiation:** Invest in R&D to continuously innovate and add unique features that differentiate these products from competitors. Focus on tangible improvements that customers can appreciate.
# *   **High-Quality Sourcing:** Prioritize sourcing high-quality materials and components to ensure product durability and performance, which is a key expectation for this price segment.
# *   **Demand Forecasting and Strategic Stocking:** Maintain adequate inventory to meet demand, especially for popular items, but avoid overstocking to prevent tying up capital. Utilize advanced analytics for accurate forecasting.
# *   **Customer Co-Creation/Feedback Loops:** Engage with customers for feedback on potential new features or improvements, making them feel part of the product development process.
# *   **Cross-Selling and Upselling:** Leverage these products as a stepping stone. Cross-sell complementary high-margin accessories or gently upsell to premium products (Cluster 3) for customers seeking the absolute best.

# %% [markdown]
# ### Recommendations for Premium/High-Value Products (Cluster 3)
#
# Cluster 3 represents the highest prices (average $109.28) and COGS (average $41.69), indicative of premium or high-value products. Strategies for this segment should focus on exclusivity, superior quality, unique experiences, and brand prestige.
#
# #### 1. Marketing Strategies:
# *   **Exclusivity and Prestige Messaging:** Emphasize the rarity, craftsmanship, and superior performance of these products. Use language that conveys luxury, sophistication, and belonging to an elite group. Target aspirations and status.
# *   **Experience-Based Marketing:** Create marketing campaigns that highlight the unique experience of owning and using the product. This could involve exclusive events, personalized demonstrations, or immersive digital content.
# *   **Brand Storytelling:** Develop a compelling narrative around the product's origin, design philosophy, and the quality of materials/craftsmanship. This builds emotional connection and justifies the high price.
# *   **Partnerships with Luxury Brands/Influencers:** Collaborate with non-competing luxury brands or high-net-worth influencers who align with the product's image to reach the target affluent audience.
# *   **Limited Editions and Scarcity:** Introduce limited-edition versions or communicate scarcity to enhance desirability and create a sense of urgency.
#
# #### 2. Pricing Adjustments:
# *   **Premium Pricing Strategy:** Maintain high price points to reinforce the product's premium status. Price reductions should be rare and carefully managed to avoid devaluing the brand (e.g., exclusive sales for loyal customers).
# *   **Value-Added Services and Customization:** Offer white-glove delivery, bespoke customization options, extended premium support, or exclusive membership benefits to justify the price and enhance the customer experience.
# *   **Bundling with High-End Accessories:** Create bundles that include other high-end, complementary products or services that further elevate the perceived value.
# *   **Financing Options for High-Ticket Items:** While targeting affluent customers, providing discrete high-end financing options can make these products accessible to a slightly broader premium market.
#
# #### 3. Product Development and Inventory Management:
# *   **Uncompromising Quality and Innovation:** Invest heavily in R&D to deliver cutting-edge features, superior materials, and unmatched performance. Continuous innovation is key to staying competitive in the premium market.
# *   **Exclusive Sourcing and Craftsmanship:** Prioritize the highest quality, ethically sourced materials and skilled craftsmanship. Transparency in sourcing and production can be a powerful marketing tool.
# *   **Controlled Inventory and Exclusivity:** Maintain very tight inventory control to preserve exclusivity and avoid oversupply. Production should often be limited to demand, enhancing the product's allure and preventing discounting.
# *   **Personalized Product Development:** Offer options for customization or co-creation with customers for truly bespoke experiences.
# *   **Lifetime Value Focus:** Develop products and services that encourage repeat purchases or upgrades within the premium segment, focusing on the long-term relationship with high-value customers.

# %% [markdown]
# ### Summary of Actionable Recommendations for All Product Clusters
#
# By segmenting products into four distinct clusters based on their price and COGS, we can tailor strategies to maximize engagement, sales, and profitability for each. Here’s a summary of how these strategies align to achieve overall business objectives:
#
# #### Cluster 0: Entry-Level/Budget-Friendly Products (Lowest Price/COGS)
# *   **Objective:** Maximize volume, attract new customers, and drive initial engagement.
# *   **Key Strategies:**
#     *   **Marketing:** Value-oriented messaging, broad digital advertising, partnerships/bundles, user-generated content.
#     *   **Pricing:** Competitive pricing, frequent promotions (BOGO, discounts), subscription models, tiered basic options.
#     *   **Product/Inventory:** Cost-efficient production, just-in-time inventory, product simplification, expanding basic lines, careful cross-selling.
# *   **Impact:** Drives market penetration, captures price-sensitive buyers, and creates a large customer base for potential future upsells.
#
# #### Cluster 1: Standard/Mid-Range Products (Mid-Range Price/COGS)
# *   **Objective:** Retain customers, expand market share, and deliver consistent value.
# *   **Key Strategies:**
#     *   **Marketing:** Quality-value proposition, benefit-oriented advertising, customer testimonials, content marketing, demographic-targeted ads.
#     *   **Pricing:** Value pricing (avoid deep discounts), strategic bundling, loyalty programs, seasonal promotions.
#     *   **Product/Inventory:** Feature enhancement, high quality control, optimized inventory, customer feedback integration, soft upselling to premium.
# *   **Impact:** Builds customer loyalty, ensures steady revenue, and serves as a bridge between entry-level and higher-end offerings.
#
# #### Cluster 2: Higher Mid-Range Products (Higher Mid-Range Price/COGS)
# *   **Objective:** Attract discerning customers, justify higher price points, and showcase advanced features.
# *   **Key Strategies:**
#     *   **Marketing:** Feature-rich communication, premium branding, influencer/expert reviews, lifestyle-oriented advertising, comparative marketing.
#     *   **Pricing:** Premium pricing (minimal discounts), value-added services (extended warranties), exclusive bundles, financing options.
#     *   **Product/Inventory:** Innovation/differentiation, high-quality sourcing, strategic stocking with analytics, customer co-creation, cross-selling/upselling within premium.
# *   **Impact:** Appeals to customers seeking enhanced quality without top-tier luxury, boosts average transaction value, and strengthens brand reputation for innovation.
#
# #### Cluster 3: Premium/High-Value Products (Highest Price/COGS)
# *   **Objective:** Reinforce exclusivity, deliver unique experiences, and cultivate brand prestige.
# *   **Key Strategies:**
#     *   **Marketing:** Exclusivity/prestige messaging, experience-based marketing, brand storytelling, luxury brand partnerships, limited editions/scarcity.
#     *   **Pricing:** Premium pricing (rare, managed discounts), value-added services/customization, high-end accessory bundling, discreet financing.
#     *   **Product/Inventory:** Uncompromising quality/innovation, exclusive sourcing/craftsmanship, controlled inventory for exclusivity, personalized product development, focus on lifetime value.
# *   **Impact:** Generates high-profit margins, enhances brand image, attracts affluent customers, and drives long-term customer relationships.
#
# **Overall Conclusion:** By implementing these tailored strategies, the business can effectively cater to diverse customer needs and price sensitivities across its product portfolio. This approach not only optimizes sales and profitability for each segment but also creates a cohesive brand ecosystem that encourages customer progression through different product tiers, ultimately maximizing overall revenue and customer lifetime value.

# %% [markdown]
# The task asked to summarize actionable recommendations for four product clusters, highlighting strategies to maximize engagement, sales, and profitability for each, considering their distinct price and COGS characteristics. The solution provided tailored recommendations for each cluster:
#
# *   **Entry-Level/Budget-Friendly Products (Cluster 0)**: Recommendations centered on maximizing volume and customer accessibility through value-oriented marketing, competitive pricing (average price: \$50.82, average COGS: \$19.34), frequent promotions, and cost-efficient production with just-in-time inventory.
# *   **Standard/Mid-Range Products (Cluster 1)**: Strategies focused on balancing quality and value, competitive differentiation, and expanding market share. This involved benefit-oriented marketing, value pricing (average price: \$79.28, average COGS: \$28.11) with loyalty programs, feature enhancement, and optimized inventory levels.
# *   **Higher Mid-Range Products (Cluster 2)**: The focus was on emphasizing advanced features, superior quality, and a premium experience. Recommendations included feature-rich communication, premium branding, maintaining a price (average price: \$94.48, average COGS: \$33.48) that reflects enhanced value, value-added services, and continuous innovation with high-quality sourcing.
# *   **Premium/High-Value Products (Cluster 3)**: Strategies aimed at reinforcing exclusivity, delivering unique experiences, and cultivating brand prestige. This involved exclusivity messaging, experience-based marketing, maintaining high price points (average price: \$109.28, average COGS: \$41.69) with rare discounts, value-added services/customization, uncompromising quality, and controlled inventory for exclusivity.
#
# Data Analysis Key Findings
# *   **Cluster 0 (Entry-Level/Budget-Friendly)**: These products have the lowest average price (\$50.82) and COGS (\$19.34). Recommendations emphasize value-oriented messaging, competitive pricing, frequent promotions like "Buy One Get One Free" (BOGO), and cost-efficient production to drive high volume and attract new customers.
# *   **Cluster 1 (Standard/Mid-Range)**: With mid-range average prices (\$79.28) and COGS (\$28.11), the focus is on a quality-value proposition. Strategies include benefit-oriented advertising, strategic bundling, loyalty programs to retain customers, and continuous feature enhancement through customer feedback.
# *   **Cluster 2 (Higher Mid-Range)**: Positioned with higher mid-range prices (\$94.48) and elevated COGS (\$33.48), the recommendations stress advanced features and superior quality. This involves feature-rich communication, premium branding, value-added services (e.g., extended warranties), and investment in R&D for innovation.
# *   **Cluster 3 (Premium/High-Value)**: These products command the highest average prices (\$109.28) and COGS (\$41.69). Strategies prioritize exclusivity, prestige messaging, experience-based marketing, maintaining high price points with rare managed discounts, uncompromising quality, and controlled inventory to preserve allure.
#
# Insights or Next Steps
# *   Implementing these tailored strategies for each product cluster can optimize sales and profitability by effectively catering to diverse customer needs and price sensitivities across the product portfolio.
# *   This segmented approach fosters a cohesive brand ecosystem, encouraging customer progression through different product tiers, which can maximize overall revenue and customer lifetime value.
